# %%
"""
Run detetection for DCLDE 2018
Run multiple models on multiple days and then generate performance numbers and figures
Created on Wed May  2 14:47:09 2018
@author: ys587
"""
import os, sys
ROOT_DIR = os.path.abspath("/home/ys587/tensorflow3/upcall-basic-net") 
# the path where upcall-basic-net is
sys.path.append(ROOT_DIR)

from upcall.accuracy_measure import map_build_day_file
import glob, os
from upcall.config import Config
from upcall.full_process import full_process_interface
# Out:
# /home/ys587/tensorflow3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Parameter
config = Config()

DATA_DIR = r'/home/ys587/__Data'
# truth data:
TruthFolder = r'/home/ys587/__Data/__TruthLabelVAPlusStAndrew'
day_file_map = map_build_day_file(TruthFolder)

# testing sound stream of St Andrew DCL
SoundPath = os.path.join(DATA_DIR, r'DCL_St_Andrew/Sound_3_days')
day_list = sorted(glob.glob(os.path.join(SoundPath+'/','*')))

# %%
# Inference
expt_label = 'Test detection'
classifier_file = r'weights-improvement-38-0.8361.hdf5'
classifier_path = r'/home/ys587/__Data/DetectionTestCase/'
seltab_detect_path = '/home/ys587/__Data/DetectionTestCase/DetectionResults'
full_process_interface(expt_label, day_list, classifier_file, classifier_path, seltab_detect_path, day_file_map, config)
# Out:
# Test detection
#
# /home/ys587/__Data/DCL_St_Andrew/Sound_3_days/NOPP6_EST_20090401
# NOPP6_EST_20090401_000000
# #==>> [8029 8769]
# Found event: 1 Time1: 802.9000 Score: 0.91403514
# Found event: 2 Time1: 876.9000 Score: 0.95454776
#
# NOPP6_EST_20090401_001500
# #==>> [2025 2247 2362 2453 3627 4315 4750 5303 5366 5477 5696 6617 7338 7914
#  8576]
# Found event: 3 Time1: 1102.5000 Score: 0.80080074
# Found event: 4 Time1: 1124.7000 Score: 0.9765228
# Found event: 5 Time1: 1136.2000 Score: 0.7454316
# Found event: 6 Time1: 1145.3000 Score: 0.80638355
# Found event: 7 Time1: 1262.7000 Score: 0.92574024
# Found event: 8 Time1: 1331.5000 Score: 0.6226743
# Found event: 9 Time1: 1375.0000 Score: 0.8391883
# Found event: 10 Time1: 1430.3000 Score: 0.6179802
# Found event: 11 Time1: 1436.6000 Score: 0.23186418
# Found event: 12 Time1: 1447.7000 Score: 0.5929345
# Found event: 13 Time1: 1469.6000 Score: 0.51054937
# Found event: 14 Time1: 1561.7000 Score: 0.512767
# Found event: 15 Time1: 1633.8000 Score: 0.666495
# Found event: 16 Time1: 1691.4000 Score: 0.36747548
# Found event: 17 Time1: 1757.6000 Score: 0.53280675
#
# NOPP6_EST_20090401_003000
# #==>> [  36  224  299  947 1072 1162 1223 1593 2031 2458 2536 2857 2909 3306
#  3390 3560 3656 4094 4202 4368 4421 4503 4825 5474 5760 5814 6372 6501
#  6572 7220 7315 7348 7402 7555 7996 8454 8631 8856]
# Found event: 18 Time1: 1803.6000 Score: 0.5144375
# Found event: 19 Time1: 1822.4000 Score: 0.2559549
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9eec5fba877b> in <module>()
#       4 classifier_path = r'/home/ys587/__Data/DetectionTestCase/'
#       5 seltab_detect_path = '/home/ys587/__Data/DetectionTestCase/DetectionResults'
# ----> 6 full_process_interface(expt_label, day_list, classifier_file, classifier_path, seltab_detect_path, day_file_map, config)
#
# ~/tensorflow3/upcall-basic-net/upcall/full_process.py in full_process_interface(expt_label, day_list, classifier_file, classifier_path, seltab_detect_path, day_file_map, config)
#      24     if not os.path.exists(seltab_detect_path):
#      25         os.makedirs(seltab_detect_path)
# ---> 26     full_process(expt_label, day_list, classifier_model, seltab_detect_path, day_file_map, config)
#
# ~/tensorflow3/upcall-basic-net/upcall/full_process.py in full_process(expt_label, day_list, classifier_model, seltab_detect_path, day_file_map, config)
#      12     print(expt_label)
#      13     if config.ACCU_ONLY is False:
# ---> 14         run_detector_days(day_list, seltab_detect_path, classifier_model, config)
#      15
#      16     accu_result_path = seltab_detect_path+'/__TP_FN_FP'
#
# ~/tensorflow3/upcall-basic-net/upcall/detection.py in run_detector_days(day_sound_path_list, seltab_out_path, classifier_model_path, config)
#      72     for dd in day_sound_path_list:
#      73         print('\n'+dd)
# ---> 74         seltab_detected = run_detector(dd, seltab_out_path, classifier_model_path, config)
#      75     stop_time = timeit.default_timer()
#      76     print('Runtime: '+str.format("{0:=.4f}", stop_time - start_time)+' Sec')
#
# ~/tensorflow3/upcall-basic-net/upcall/detection.py in run_detector(day_sound_path, seltab_out_path, classifier_model_path, config)
#     124             for ss in range(ss_last):
#     125                 samples = samples0[ss*config.FRAME_STEP:ss*config.FRAME_STEP+config.FRAME_SIZE,cc]
# --> 126                 spectro = preprocess(samples, config)
#     127
#     128                 spectro_list.append(spectro)
#
# ~/tensorflow3/upcall-basic-net/upcall/sound_util.py in preprocess(sample_clip, config)
#      23     """
#      24     sftf_mat = np.abs(librosa.stft(sample_clip, n_fft=config.FFT_SIZE,
# ---> 25                                   hop_length=config.HOP_SIZE))
#      26     spectro = sftf_mat[config.IMG_X_START:(config.IMG_X_START+config.IMG_X),
#      27                       config.IMG_Y_START:(config.IMG_Y_START+config.IMG_Y)].flatten()
#
# ~/tensorflow3/lib/python3.5/site-packages/librosa/core/spectrum.py in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     180         # RFFT and Conjugate here to match phase from DPWE code
#     181         stft_matrix[:, bl_s:bl_t] = fft.fft(fft_window *
# --> 182                                             y_frames[:, bl_s:bl_t],
#     183                                             axis=0)[:stft_matrix.shape[0]]
#     184
#
# KeyboardInterrupt:
