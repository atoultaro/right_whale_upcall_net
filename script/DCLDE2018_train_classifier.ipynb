# %%
"""
build the convnet model, prepare training data and run the classifier 
training

Args:
    LabelFile: the truth label in txt file
    SoundPath: path to the training sound files
    config (class object): configuration parameters 
    check_path: output path of training results
Returns:
    True if the function runs well
"""
import os, sys
ROOT_DIR = os.path.abspath("/home/ys587/tensorflow3/upcall-basic-net") 
# the path where upcall-basic-net is
sys.path.append(ROOT_DIR)

from upcall.config import Config
#from upcall.train_classifier import lenet, lenet_dropout_input, lenet_dropout_conv
from upcall.train_classifier import lenet, lenet_dropout_input, \
    lenet_dropout_conv, lenet_dropout_input_conv, birdnet, \
    birdnet_dropout_input, birdnet_dropout_conv, birdnet_dropout_input_conv
from upcall.train_classifier import model_preprocess, net_train
from script.DCLDE2018_train_data import prepare_truth_data
import time
# Out:
# /home/ys587/tensorflow3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
start_time = time.time()

#config = Config('Data_4', 'Birdnet_dropout_input_conv')
config = Config('Data_1', 'Birdnet_dropout_input_conv')
#config = Config('Data_1', 'Lenet_dropout_conv') # model of the test case 38-0.8361.hdf5

config.TRAIN_RESULT_PATH = r'/tmp/Model'

##################################
# Model DCLDE 2018 # Build models here
##################################
if config.MODEL == r'Lenet':
    model = lenet(config)
elif config.MODEL == r'Lenet_dropout_input':
    model = lenet_dropout_input(config)
elif config.MODEL == r'Lenet_dropout_conv':
    model = lenet_dropout_conv(config)
elif config.MODEL == r'Lenet_dropout_input_conv':
    model = lenet_dropout_input_conv(config)
    
elif config.MODEL == r'Birdnet':
    model = birdnet(config)
elif config.MODEL == r'Birdnet_dropout_input':
    model = birdnet_dropout_input(config)
elif config.MODEL == r'Birdnet_dropout_conv':
    model = birdnet_dropout_conv(config)
elif config.MODEL == r'Birdnet_dropout_input_conv':
    model = birdnet_dropout_input_conv(config)
    
model = model_preprocess(model, config)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_1 (Dropout)          (None, 40, 40, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 40, 40, 64)        640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40, 40, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 20, 20, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 1024)        4719616
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 1024)        4096
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 1024)        1049600
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 7,329,026
# Trainable params: 7,325,058
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
label, feature = prepare_truth_data(config)
##random.seed(a = 29) # seed to randomly sample of training data
        
net_train(feature, label, model, config)

print('The run time of training the classifier is '+str(time.time() - start_time)+' Sec')
# Out:
# Extract features from Kaggle:
# Train on 24000 samples, validate on 6000 samples
# Epoch 1/100
# 24000/24000 [==============================] - 8s 350us/step - loss: 0.8906 - F1_Class: nan - val_loss: 0.3668 - val_F1_Class: nan
#
# Epoch 00001: val_F1_Class did not improve from -inf
# Epoch 2/100
# 24000/24000 [==============================] - 5s 217us/step - loss: 0.6854 - F1_Class: 0.1327 - val_loss: 0.2897 - val_F1_Class: 0.2088
#
# Epoch 00002: val_F1_Class improved from -inf to 0.20883, saving model to /tmp/Model/epoch_02_F1_0.2088.hdf5
# Epoch 3/100
# 24000/24000 [==============================] - 5s 218us/step - loss: 0.6307 - F1_Class: 0.0606 - val_loss: 0.2741 - val_F1_Class: 0.0750
#
# Epoch 00003: val_F1_Class did not improve from 0.20883
# Epoch 4/100
# 24000/24000 [==============================] - 5s 218us/step - loss: 0.6188 - F1_Class: 0.0526 - val_loss: 0.2704 - val_F1_Class: 0.12714
#
# Epoch 00004: val_F1_Class did not improve from 0.20883
# Epoch 5/100
# 24000/24000 [==============================] - 5s 218us/step - loss: 0.6113 - F1_Class: 0.0762 - val_loss: 0.2760 - val_F1_Class: 0.1815
#
# Epoch 00005: val_F1_Class did not improve from 0.20883
# Epoch 6/100
# 24000/24000 [==============================] - 5s 218us/step - loss: 0.6087 - F1_Class: 0.1039 - val_loss: 0.2732 - val_F1_Class: 0.1506
#
# Epoch 00006: val_F1_Class did not improve from 0.20883
# Epoch 7/100
# 24000/24000 [==============================] - 5s 219us/step - loss: 0.6054 - F1_Class: 0.0782 - val_loss: 0.2752 - val_F1_Class: 0.1469
#
# Epoch 00007: val_F1_Class did not improve from 0.20883
# Epoch 8/100
# 24000/24000 [==============================] - 5s 218us/step - loss: 0.6046 - F1_Class: 0.0977 - val_loss: 0.2854 - val_F1_Class: 0.1307
#
# Epoch 00008: val_F1_Class did not improve from 0.20883
# Epoch 9/100
# 11000/24000 [============>.................] - ETA: 2s - loss: 0.6033 - F1_Class: 0.1487 ETA: 3s - loss: 0.6071 - F1_Cla
